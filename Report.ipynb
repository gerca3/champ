# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd
import gpxpy
import os
from shapely.geometry import box, LineString
import matplotlib.pyplot as plt
import contextily as ctx
import time
import psycopg2
import cv2
import time
import math
import datetime

# %%
links = []

with open("./Links.txt", mode="r", encoding="UTF-8") as f:
    for i in f:
        links.append(i.strip())

# %%
links
# Out:
# ['https://caucasia.ru/gpx/8EWQAV62.gpx',
#  'https://caucasia.ru/gpx/CPOQQN9R.gpx',
#  'https://caucasia.ru/gpx/CVBOS4W2.gpx',
#  'https://caucasia.ru/gpx/HTGT4UOT.gpx',
#  'https://caucasia.ru/gpx/HQUWT5UB.gpx',
#  'https://caucasia.ru/gpx/S87VDJ9R.gpx',
#  'https://caucasia.ru/gpx/XKSRMH5L.gpx',
#  'https://caucasia.ru/gpx/S87VDJ9R.gpx',
#  'https://caucasia.ru/gpx/G6I1K7J9.gpx']

# %%
for num, url in enumerate(links):
    try:
        response = requests.get(url)
        filename = f"track{num}.gpx"
        
        with open(f"data/gpx/{filename}", mode="wb") as f:
            f.write(response.content)
    except Exception as e:
        print("Ошибка при скачивании")

# %%
gpx_list = os.listdir("data/gpx")

# %%
gpx_list
# Out:
# ['track0.gpx',
#  'track2.gpx',
#  'track7.gpx',
#  'track3.gpx',
#  'track4.gpx',
#  'track8.gpx',
#  'track1.gpx',
#  'track6.gpx',
#  'track5.gpx']

# %%
margin = 0.02

for file in gpx_list:
    with open(f"{"data/gpx"}/{file}", mode="r", encoding="UTF-8") as f:
        gpx = gpxpy.parse(f)

    lats, lons, alts = [], [], []
    result = []
    time_list = []
    for track in gpx.tracks:
        for segment in track.segments:
            for point in segment.points:
                lats.append(point.latitude)
                lons.append(point.longitude)
                alts.append(point.elevation)
                result.append({
                        "track_id": file,
                        "analysis_date": point.time.date(),
                        "latitude": point.latitude,
                        "longitude": point.longitude,
                        "altitude": point.elevation})
                
    bbox = box(
            min(lons) - margin,
            min(lats) - margin,
            max(lons) + margin,
            max(lats) + margin
        )
    track_line = LineString(zip(lons, lats))

    gdf_bbox = gpd.GeoDataFrame(geometry=[bbox], crs="EPSG:4326")
    gdf_bbox_web = gdf_bbox.to_crs(epsg=3857)

    gdf_track = gpd.GeoDataFrame(geometry=[track_line], crs="EPSG:4326")
    gdf_track_web = gdf_track.to_crs(epsg=3857)

    _, ax = plt.subplots(figsize=(10, 8))

    gdf_bbox_web.plot(ax=ax, alpha=0)
    gdf_track_web.plot(ax=ax, color="red", linewidth=2)

    ctx.add_basemap(ax, crs=gdf_bbox_web.crs, source=ctx.providers.OpenStreetMap.Mapnik)

    ax.set_axis_off()
    os.makedirs("data/image", exist_ok=True)

    plt.savefig(f"{"data/image"}/{file[:-4]}", dpi=150, bbox_inches="tight", pad_inches=0)
    plt.close()

# %%
from geopy.distance import geodesic

def distance(lat1, lon1, lat2, lon2):
    """
    Рассчитывает расстояние между двумя точками на Земле
    """
    
    point1 = (lat1, lon1)
    point2 = (lat2, lon2)
    
    distance = geodesic(point1, point2).kilometers
    return distance

# %%
names_json = []
ll = list(zip(lats, lons))

# %%
for lat, lon in (ll[0], ll[len(ll)//5],  ll[len(ll)//2], ll[len(ll)//3],  ll[-1]):
        try:
            headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
            response = requests.get(f"https://nominatim.openstreetmap.org/reverse?lat={lat}&lon={lon}&format=json", headers=headers)
            print(response)
            json = response.json()
            time.sleep(3)

            names_json.append(json["display_name"])
        except Exception as e:
            print(f"Возникла ошибка при получении данных с API: {e}")
# Out:
# <Response [403]>
# Возникла ошибка при получении данных с API: Expecting value: line 1 column 1 (char 0)
# <Response [403]>
# Возникла ошибка при получении данных с API: Expecting value: line 1 column 1 (char 0)
# <Response [403]>
# Возникла ошибка при получении данных с API: Expecting value: line 1 column 1 (char 0)
# <Response [200]>
# <Response [200]>

# %%
names_json
# Out:
# ['Одичавшая, Голубинское сельское поселение, Бахчисарайский район, Автономна Республіка Крим, 298475, Україна',
#  'Поляна, Голубинское сельское поселение, Бахчисарайский район, Автономна Республіка Крим, 298474, Україна']

# %%
try:
    connect = psycopg2.connect(
            database="db_arthur", 
            user="arthur", 
            password="146a",
            host="localhost",
            port=5430
    )
    cursor = connect.cursor()

    cursor.execute("""
        CREATE TABLE IF NOT EXISTS track_analysis (
            id SERIAL PRIMARY KEY,
            track_id VARCHAR,
            analysis_date DATE,
            region VARCHAR,
            latitude DOUBLE PRECISION,
            longitude DOUBLE PRECISION,
            altitude DOUBLE PRECISION,
            step_frequency DOUBLE PRECISION,
            temperature DOUBLE PRECISION,
            terrain_type VARCHAR,
            key_objects VARCHAR,
            created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
        )
    """)
    for i in result:
        cursor.execute("""
            INSERT INTO track_analysis
            (track_id, analysis_date, latitude, longitude, altitude)
            VALUES (%s, %s, %s, %s, %s)
        """,
            (i["track_id"],
            i["analysis_date"],
            i["latitude"],
            i["longitude"],
            i["altitude"],))

    connect.commit()
except Exception as e:
    print(f"Ошибка при создании базы данных: {e}")
finally:
    if connect:
        cursor.close()
        connect.close()

# %%
df_test = pd.read_sql_table(table_name="track_analysis", con="postgresql://arthur:146a@localhost:5430/db_arthur", schema="public", parse_dates=["analysis_date", "created_at"])

# %%
df_test
# Out:
#         id    track_id analysis_date region   latitude  longitude  altitude  \
# 0        1  track5.gpx    2021-01-05   None  44.551723  33.899745    333.06
# 1        2  track5.gpx    2021-01-05   None  44.551987  33.900377    326.65
# 2        3  track5.gpx    2021-01-05   None  44.551972  33.900550    325.74
# 3        4  track5.gpx    2021-01-05   None  44.551773  33.900948    325.13
# 4        5  track5.gpx    2021-01-05   None  44.551453  33.901415    323.30
# ...    ...         ...           ...    ...        ...        ...       ...
# 3360  3361  track5.gpx    2021-01-05   None  44.550820  33.899888    311.70
# 3361  3362  track5.gpx    2021-01-05   None  44.551270  33.899987    310.18
# 3362  3363  track5.gpx    2021-01-05   None  44.551492  33.899950    311.09
# 3363  3364  track5.gpx    2021-01-05   None  44.551735  33.899732    313.53
# 3364  3365  track5.gpx    2021-01-05   None  44.551715  33.899775    315.06
#
#       step_frequency  temperature terrain_type key_objects  \
# 0                NaN          NaN         None        None
# 1                NaN          NaN         None        None
# 2                NaN          NaN         None        None
# 3                NaN          NaN         None        None
# 4                NaN          NaN         None        None
# ...              ...          ...          ...         ...
# 3360             NaN          NaN         None        None
# 3361             NaN          NaN         None        None
# 3362             NaN          NaN         None        None
# 3363             NaN          NaN         None        None
# 3364             NaN          NaN         None        None
#
#                      created_at
# 0    2026-01-16 08:42:18.310703
# 1    2026-01-16 08:42:18.310703
# 2    2026-01-16 08:42:18.310703
# 3    2026-01-16 08:42:18.310703
# 4    2026-01-16 08:42:18.310703
# ...                         ...
# 3360 2026-01-16 10:13:08.602973
# 3361 2026-01-16 10:13:08.602973
# 3362 2026-01-16 10:13:08.602973
# 3363 2026-01-16 10:13:08.602973
# 3364 2026-01-16 10:13:08.602973
#
# [3365 rows x 12 columns]

# %%
result
# Out:
# [{'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551723,
#   'longitude': 33.899745,
#   'altitude': 333.06},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551987,
#   'longitude': 33.900377,
#   'altitude': 326.65,
#   'avg_temperature': 10.5},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551972,
#   'longitude': 33.90055,
#   'altitude': 325.74,
#   'avg_temperature': 10.5},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551773,
#   'longitude': 33.900948,
#   'altitude': 325.13,
#   'avg_temperature': 10.5},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551453,
#   'longitude': 33.901415,
#   'altitude': 323.3,
#   'avg_temperature': 10.4},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551197,
#   'longitude': 33.902472,
#   'altitude': 315.67},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.550988,
#   'longitude': 33.902668,
#   'altitude': 311.7},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.550745,
#   'longitude': 33.90301,
#   'altitude': 308.05},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.550063,
#   'longitude': 33.904228,
#   'altitude': 313.53},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54999,
#   'longitude': 33.904223,
#   'altitude': 314.76},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.549558,
#   'longitude': 33.90461,
#   'altitude': 321.46},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.549413,
#   'longitude': 33.90465,
#   'altitude': 325.43},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548967,
#   'longitude': 33.904925,
#   'altitude': 331.84},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548737,
#   'longitude': 33.904918,
#   'altitude': 334.28},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548648,
#   'longitude': 33.904867,
#   'altitude': 335.8},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548205,
#   'longitude': 33.905027,
#   'altitude': 341.6},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548057,
#   'longitude': 33.905037,
#   'altitude': 342.82},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54791,
#   'longitude': 33.905132,
#   'altitude': 343.73},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547557,
#   'longitude': 33.905203,
#   'altitude': 346.17},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547203,
#   'longitude': 33.90539,
#   'altitude': 349.22},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547017,
#   'longitude': 33.905673,
#   'altitude': 351.66},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54667,
#   'longitude': 33.90582,
#   'altitude': 355.93},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546453,
#   'longitude': 33.905858,
#   'altitude': 360.51},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546088,
#   'longitude': 33.906068,
#   'altitude': 364.17},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.545752,
#   'longitude': 33.906425,
#   'altitude': 369.05},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.545673,
#   'longitude': 33.906433,
#   'altitude': 370.88},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.545448,
#   'longitude': 33.906327,
#   'altitude': 369.05},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54514,
#   'longitude': 33.906435,
#   'altitude': 367.52},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54492,
#   'longitude': 33.906443,
#   'altitude': 369.35},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.544668,
#   'longitude': 33.906578,
#   'altitude': 371.79},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54456,
#   'longitude': 33.90671,
#   'altitude': 372.71},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.544473,
#   'longitude': 33.906743,
#   'altitude': 375.15},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.544312,
#   'longitude': 33.90703,
#   'altitude': 376.98},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.544323,
#   'longitude': 33.907125,
#   'altitude': 377.28},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.544393,
#   'longitude': 33.907197,
#   'altitude': 378.2},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.544343,
#   'longitude': 33.907328,
#   'altitude': 379.72},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.544342,
#   'longitude': 33.907462,
#   'altitude': 385.21},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54443,
#   'longitude': 33.907222,
#   'altitude': 387.96},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.

#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.535582,
#   'longitude': 33.921208,
#   'altitude': 884.8},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.535463,
#   'longitude': 33.92132,
#   'altitude': 886.02},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.535573,
#   'longitude': 33.921257,
#   'altitude': 885.72},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.535347,
#   'longitude': 33.921345,
#   'altitude': 884.5},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.534985,
#   'longitude': 33.92168,
#   'altitude': 878.4},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.534852,
#   'longitude': 33.921888,
#   'altitude': 875.35},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.534313,
#   'longitude': 33.921788,
#   'altitude': 868.64},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.5342,
#   'longitude': 33.921885,
#   'altitude': 864.67},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.534047,
#   'longitude': 33.921735,
#   'altitude': 860.1},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53394,
#   'longitude': 33.921932,
#   'altitude': 857.66},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533903,
#   'longitude': 33.922148,
#   'altitude': 857.05},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533995,
#   'longitude': 33.922353,
#   'altitude': 855.83},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533862,
#   'longitude': 33.922618,
#   'altitude': 853.69},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533528,
#   'longitude': 33.922905,
#   'altitude': 852.47},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533508,
#   'longitude': 33.923033,
#   'altitude': 853.39},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53338,
#   'longitude': 33.92284,
#   'altitude': 853.39},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533277,
#   'longitude': 33.922797,
#   'altitude': 853.69},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.532927,
#   'longitude': 33.922825,
#   'altitude': 854.61},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53294,
#   'longitude': 33.922898,
#   'altitude': 854.91},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53302,
#   'longitude': 33.922858,
#   'altitude': 854.61},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53336,
#   'longitude': 33.92295,
#   'altitude': 853.39},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533395,
#   'longitude': 33.923002,
#   'altitude': 852.78},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533387,
#   'longitude': 33.923155,
#   'altitude': 851.86},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533468,
#   'longitude': 33.92325,
#   'altitude': 851.25},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533668,
#   'longitude': 33.923338,
#   'altitude': 848.51},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533723,
#   'longitude': 33.923463,
#   'altitude': 847.29},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533973,
#   'longitude': 33.923493,
#   'altitude': 844.85},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.534068,
#   'longitude': 33.92361,
#   'altitude': 843.02},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533965,
#   'longitude': 33.923472,
#   'altitude': 839.97},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533667,
#   'longitude': 33.923373,
#   'altitude': 840.58},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533612,
#   'longitude': 33.923308,
#   'altitude': 841.19},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533553,
#   'longitude': 33.92333,
#   'altitude': 841.49},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533383,
#   'longitude': 33.923158,
#   'altitude': 843.93},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533402,
#   'longitude': 33.922973,
#   'altitude': 844.54},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.533068,
#   'longitude': 33.922795,
#   'altitude': 846.98},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.532812,
#   'longitude': 33.922867,
#   'altitude': 848.51},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53229,
#   'longitude': 33.923227,
#   'altitude': 857.96},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.531878,
#   'longitude': 33.923368,
#   'altitude': 859.18},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53147,
#   'longitude': 33.923318,
#   'altitude': 861.93},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530967,
#   'longitude': 33.923085,
#   'altitude': 870.47},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530385,
#   'longitude': 33.923098,
#   'altitude': 877.79},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.5302,
#   'longitude': 33.923,
#   'altitude': 880.53},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530058,
#   'longitude': 33.922833,
#   'altitude': 882.97},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529662,
#   'longitude': 33.9226,
#   'altitude': 886.02},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529437,
#   'longitude': 33.922372,
#   'altitude': 894.26},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529367,
#   'longitude': 33.922405,
#   'altitude': 888.77},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528508,
#   'longitude': 33.92185,
#   'altitude': 873.52},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528045,
#   'longitude': 33.921625,
#   'altitude': 865.89},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52789,
#   'longitude': 33.921475,
#   'altitude': 863.45},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.527733,
#   'longitude': 33.921112,
#   'altitude': 860.4},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.527383,
#   'longitude': 33.920672,
#   'altitude': 855.83},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.527188,
#   'longitude': 33.920577,
#   'altitude': 853.08},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.526608,
#   'longitude': 33.920442,
#   'altitude': 850.34},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.526133,
#   'longitude': 33.920003,
#   'altitude': 849.42},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.526087,
#   'longitude': 33.919895,
#   'altitude': 849.42},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525788,
#   'longitude': 33.91959,
#   'altitude': 847.29},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525658,
#   'longitude': 33.919298,
#   'altitude': 847.59},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525547,
#   'longitude': 33.919178,
#   'altitude': 847.9},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525488,
#   'longitude': 33.918682,
#   'altitude': 846.37},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525342,
#   'longitude': 33.918272,
#   'altitude': 845.45},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525332,
#   'longitude': 33.918052,
#   'altitude': 845.45},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525137,
#   'longitude': 33.91767,
#   'altitude': 844.54},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525343,
#   'longitude': 33.917362,
#   'altitude': 845.45},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525443,
#   'longitude': 33.916698,
#   'altitude': 843.63},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525692,
#   'longitude': 33.916127,
#   'altitude': 843.93},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525643,
#   'longitude': 33.915813,
#   'altitude': 842.1},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525667,
#   'longitude': 33.915407,
#   'altitude': 841.8},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525602,
#   'longitude': 33.914728,
#   'altitude': 840.27},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525482,
#   'longitude': 33.914463,
#   'altitude': 839.66},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525427,
#   'longitude': 33.913982,
#   'altitude': 840.27},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52538,
#   'longitude': 33.91382,
#   'altitude': 841.49},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525428,
#   'longitude': 33.913337,
#   'altitude': 844.54},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525328,
#   'longitude': 33.913028,
#   'altitude': 844.24},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52529,
#   'longitude': 33.912748,
#   'altitude': 843.32},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525317,
#   'longitude': 33.912437,
#   'altitude': 846.07},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525258,
#   'longitude': 33.91221,
#   'altitude': 846.37},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52536,
#   'longitude': 33.910157,
#   'altitude': 839.36},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52548,
#   'longitude': 33.909997,
#   'altitude': 836.31},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.525642,
#   'longitude': 33.909965,
#   'altitude': 833.26},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.526238,
#   'longitude': 33.90955,
#   'altitude': 822.28},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.526827,
#   'longitude': 33.908998,
#   'altitude': 807.64},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.527135,
#   'longitude': 33.908893,
#   'altitude': 800.32},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.527568,
#   'longitude': 33.90886,
#   'altitude': 792.08},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.527928,
#   'longitude': 33.908683,
#   'altitude': 787.2},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528022,
#   'longitude': 33.908577,
#   'altitude': 785.07},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52828,
#   'longitude': 33.908532,
#   'altitude': 781.41},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528425,
#   'longitude': 33.908413,
#   'altitude': 779.88},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528477,
#   'longitude': 33.908178,
#   'altitude': 775.92},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528582,
#   'longitude': 33.907932,
#   'altitude': 773.48},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528677,
#   'longitude': 33.90742,
#   'altitude': 767.38},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.5288,
#   'longitude': 33.90719,
#   'altitude': 765.24},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52881,
#   'longitude': 33.907043,
#   'altitude': 764.63},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52872,
#   'longitude': 33.906635,
#   'altitude': 761.28},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528657,
#   'longitude': 33.905788,
#   'altitude': 757.31},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528915,
#   'longitude': 33.90531,
#   'altitude': 754.87},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529273,
#   'longitude': 33.904832,
#   'altitude': 753.96},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529352,
#   'longitude': 33.904782,
#   'altitude': 753.35},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529417,
#   'longitude': 33.904673,
#   'altitude': 753.35},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529538,
#   'longitude': 33.90428,
#   'altitude': 753.65},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529927,
#   'longitude': 33.90372,
#   'altitude': 752.74},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529898,
#   'longitude': 33.90323,
#   'altitude': 752.13},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529693,
#   'longitude': 33.902958,
#   'altitude': 750.6},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52939,
#   'longitude': 33.902665,
#   'altitude': 749.99},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529285,
#   'longitude': 33.902487,
#   'altitude': 749.08},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528657,
#   'longitude': 33.902265,
#   'altitude': 744.5},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528477,
#   'longitude': 33.902115,
#   'altitude': 745.11},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528258,
#   'longitude': 33.901705,
#   'altitude': 744.2},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528008,
#   'longitude': 33.900957,
#   'altitude': 745.42},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.527968,
#   'longitude': 33.900632,
#   'altitude': 746.64},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528017,
#   'longitude': 33.900517,
#   'altitude': 752.43},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528068,
#   'longitude': 33.900495,
#   'altitude': 753.65},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528652,
#   'longitude': 33.900538,
#   'altitude': 781.41},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.528872,
#   'longitude': 33.900677,
#   'altitude': 788.73},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.52933,
#   'longitude': 33.900707,
#   'altitude': 803.67},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529675,
#   'longitude': 33.900515,
#   'altitude': 807.64},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529837,
#   'longitude': 33.900555,
#   'altitude': 809.77},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.529932,
#   'longitude': 33.900695,
#   'altitude': 810.38},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53007,
#   'longitude': 33.900662,
#   'altitude': 811.91},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53027,
#   'longitude': 33.900747,
#   'altitude': 813.13},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530443,
#   'longitude': 33.900677,
#   'altitude': 815.57},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530597,
#   'longitude': 33.900732,
#   'altitude': 819.53},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53087,
#   'longitude': 33.900657,
#   'altitude': 828.38},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530808,
#   'longitude': 33.900595,
#   'altitude': 829.9},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53076,
#   'longitude': 33.90061,
#   'altitude': 832.04},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530825,
#   'longitude': 33.900388,
#   'altitude': 839.05},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530798,
#   'longitude': 33.90041,
#   'altitude': 846.07},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530975,
#   'longitude': 33.900455,
#   'altitude': 847.29},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.530918,
#   'longitude': 33.900508,
#   'altitude': 848.2},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.531068,
#   'longitude': 33.900742,
#   'altitude': 850.03},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.531127,
#   'longitude': 33.901013,
#   'altitude': 852.47},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.531512,
#   'longitude': 33.901435,
#   'altitude': 853.08},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.531592,
#   'longitude': 33.9014,
#   'altitude': 851.86},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.531975,
#   'longitude': 33.901498,
#   'altitude': 850.03},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53206,
#   'longitude': 33.901558,
#   'altitude': 848.81},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53224,
# ...
#   'longitude': 33.87421,
#   'altitude': 605.42},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539483,
#   'longitude': 33.874455,
#   'altitude': 598.41},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539548,
#   'longitude': 33.874838,
#   'altitude': 595.36},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53945,
#   'longitude': 33.875063,
#   'altitude': 592.91},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.53953,
#   'longitude': 33.875372,
#   'altitude': 589.87},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539553,
#   'longitude': 33.87587,
#   'altitude': 585.6},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539477,
#   'longitude': 33.876047,
#   'altitude': 584.07},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539297,
#   'longitude': 33.876122,
#   'altitude': 582.24},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539208,
#   'longitude': 33.876223,
#   'altitude': 580.72},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539105,
#   'longitude': 33.87668,
#   'altitude': 576.14},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539213,
#   'longitude': 33.8772,
#   'altitude': 574.31},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539358,
#   'longitude': 33.877552,
#   'altitude': 574.01},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539473,
#   'longitude': 33.877647,
#   'altitude': 573.4},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539535,
#   'longitude': 33.877765,
#   'altitude': 573.09},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539618,
#   'longitude': 33.878207,
#   'altitude': 576.14},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.539667,
#   'longitude': 33.878267,
#   'altitude': 575.84},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44

#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.5452,
#   'longitude': 33.88883,
#   'altitude': 427.61},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.545403,
#   'longitude': 33.888868,
#   'altitude': 423.64},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.545465,
#   'longitude': 33.889007,
#   'altitude': 421.81},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.545685,
#   'longitude': 33.889295,
#   'altitude': 419.68},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54592,
#   'longitude': 33.889793,
#   'altitude': 416.32},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546088,
#   'longitude': 33.889963,
#   'altitude': 414.8},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546593,
#   'longitude': 33.890302,
#   'altitude': 405.65},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546805,
#   'longitude': 33.890385,
#   'altitude': 398.94},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546862,
#   'longitude': 33.890465,
#   'altitude': 397.11},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546763,
#   'longitude': 33.890743,
#   'altitude': 391.31},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546735,
#   'longitude': 33.891653,
#   'altitude': 374.23},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546787,
#   'longitude': 33.892127,
#   'altitude': 366.91},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546983,
#   'longitude': 33.892955,
#   'altitude': 359.29},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546983,
#   'longitude': 33.893123,
#   'altitude': 358.37},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.546842,
#   'longitude': 33.893593,
#   'altitude': 356.24},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547028,
#   'longitude': 33.893753,
#   'altitude': 354.71},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54713,
#   'longitude': 33.893965,
#   'altitude': 354.71},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547257,
#   'longitude': 33.89455,
#   'altitude': 356.24},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547522,
#   'longitude': 33.89501,
#   'altitude': 354.71},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547563,
#   'longitude': 33.895013,
#   'altitude': 355.63},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547855,
#   'longitude': 33.89565,
#   'altitude': 352.27},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.547952,
#   'longitude': 33.895713,
#   'altitude': 351.66},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54799,
#   'longitude': 33.895998,
#   'altitude': 350.44},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54822,
#   'longitude': 33.896268,
#   'altitude': 347.39},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548232,
#   'longitude': 33.896338,
#   'altitude': 346.78},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548188,
#   'longitude': 33.896485,
#   'altitude': 345.87},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548277,
#   'longitude': 33.896883,
#   'altitude': 347.39},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548492,
#   'longitude': 33.897123,
#   'altitude': 345.26},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548863,
#   'longitude': 33.897847,
#   'altitude': 342.82},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.548983,
#   'longitude': 33.897928,
#   'altitude': 341.6},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.549075,
#   'longitude': 33.8981,
#   'altitude': 340.38},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.549045,
#   'longitude': 33.898033,
#   'altitude': 339.46},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.54936,
#   'longitude': 33.898363,
#   'altitude': 336.72},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.549518,
#   'longitude': 33.89861,
#   'altitude': 332.75},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.549967,
#   'longitude': 33.899063,
#   'altitude': 321.46},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.550057,
#   'longitude': 33.89918,
#   'altitude': 318.72},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.550075,
#   'longitude': 33.899297,
#   'altitude': 318.11},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.550392,
#   'longitude': 33.899607,
#   'altitude': 317.2},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.55082,
#   'longitude': 33.899888,
#   'altitude': 311.7},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.55127,
#   'longitude': 33.899987,
#   'altitude': 310.18},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551492,
#   'longitude': 33.89995,
#   'altitude': 311.09},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551735,
#   'longitude': 33.899732,
#   'altitude': 313.53},
#  {'track_id': 'track5.gpx',
#   'analysis_date': datetime.date(2021, 1, 5),
#   'latitude': 44.551715,
#   'longitude': 33.899775,
#   'altitude': 315.06}]

# %%
import requests
import datetime

url = "https://archive-api.open-meteo.com/v1/archive"

# Проходим по индексам 1-4 (второй-пятый элементы)
for i in range(1, 5):
    if i < len(result):  # Проверяем, что индекс существует
        point = result[i]
        lat = point["latitude"]
        lon = point["longitude"]
        date = point["analysis_date"]
        
        date_str = date.strftime("%Y-%m-%d")
        
        params = {
            'latitude': lat,
            'longitude': lon,
            'start_date': date_str,
            'end_date': date_str,
            'hourly': 'temperature_2m',
            "timezone": "auto"
        }
        
        try:
            response = requests.get(url, params=params)
            response.raise_for_status()
            
            if response.status_code == 200:
                data = response.json()
                
                if "hourly" in data and "temperature_2m" in data["hourly"]:
                    temperatures = data["hourly"]["temperature_2m"]
                    
                    if temperatures:
                        valid_temps = [t for t in temperatures if t is not None]
                        
                        if valid_temps:
                            avg_temp = sum(valid_temps) / len(valid_temps)
                            # Обновляем исходный result
                            result[i]["avg_temperature"] = round(avg_temp, 1)
                            print(f"Точка {i}: температура обновлена - {round(avg_temp, 1)}°C")
        except Exception as e:
            result[i]["avg_temperature"] = None
            print(f"Точка {i}: ошибка - {e}")

# Проверяем результат
print("\nОбновленный result:")
for i, point in enumerate(result[:6]):  # Показываем первые 6 точек
    temp = point.get('avg_temperature', 'нет данных')
    print(f"Точка {i}: ({point['latitude']}, {point['longitude']}) - температура: {temp}°C")
# Out:
# Точка 1: температура обновлена - 10.5°C
# Точка 2: температура обновлена - 10.5°C
# Точка 3: температура обновлена - 10.5°C
# Точка 4: температура обновлена - 10.4°C
#
# Обновленный result:
# Точка 0: (44.551723, 33.899745) - температура: нет данных°C
# Точка 1: (44.551987, 33.900377) - температура: 10.5°C
# Точка 2: (44.551972, 33.90055) - температура: 10.5°C
# Точка 3: (44.551773, 33.900948) - температура: 10.5°C
# Точка 4: (44.551453, 33.901415) - температура: 10.4°C
# Точка 5: (44.551197, 33.902472) - температура: нет данных°C

# %%
pd.DataFrame(result)
# Out:
#        track_id analysis_date   latitude  longitude  altitude  avg_temperature
# 0    track5.gpx    2021-01-05  44.551723  33.899745    333.06              NaN
# 1    track5.gpx    2021-01-05  44.551987  33.900377    326.65             10.5
# 2    track5.gpx    2021-01-05  44.551972  33.900550    325.74             10.5
# 3    track5.gpx    2021-01-05  44.551773  33.900948    325.13             10.5
# 4    track5.gpx    2021-01-05  44.551453  33.901415    323.30             10.4
# ..          ...           ...        ...        ...       ...              ...
# 668  track5.gpx    2021-01-05  44.550820  33.899888    311.70              NaN
# 669  track5.gpx    2021-01-05  44.551270  33.899987    310.18              NaN
# 670  track5.gpx    2021-01-05  44.551492  33.899950    311.09              NaN
# 671  track5.gpx    2021-01-05  44.551735  33.899732    313.53              NaN
# 672  track5.gpx    2021-01-05  44.551715  33.899775    315.06              NaN
#
# [673 rows x 6 columns]

# %%
url = "https://archive-api.open-meteo.com/v1/archive"

result_test = {}

for point in result[1:5]:
    lat = point["latitude"]
    lon = point["longitude"]
    date = point["analysis_date"]

    date_str = date.strftime("%Y-%m-%d")

    params = {
        'latitude': lat,
        'longitude': lon,
        'start_date': date,
        'end_date': date,
        'hourly': 'temperature_2m',
        "timezone":"auto"
    }

    response = requests.get(url, params=params)
    response.raise_for_status()
    if response.status_code == 200:
        data = response.json()
    else:
        print(f"Данные не получены")

        if "hourly" in data:
            temperatures = data["hourly"]["temperature_2m"]
            if temperatures:
                valid_temps = [t for t in temperatures if t is not None]
                if valid_temps:
                    avg_temp = sum(valid_temps) / len(valid_temps)
                    result_test.append(round(avg_temp, 1))
